# %%
import urllib.request
import json
import pandas as pd
from operator import itemgetter


client_id = "QsGAF0XwWaqBEVxrh8Ys"
client_secret = "BEu_tKAymT"

product_name = input("Enter Product Name: ")
encText = urllib.parse.quote(product_name)

items=[]
for start in range(1, 1000, 100):
    url = f"https://openapi.naver.com/v1/search/shop?query={encText}&display=100&start={start}"
    
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    
    if rescode == 200:
        response_body = response.read()
        data = json.loads(response_body.decode('utf-8'))
        
        for item in data['items']:
            try:
                item['lprice'] = int(item['lprice'])
                items.append(item)
            except ValueError:
                pass
    else:
        print("Error Code:", rescode)
        
sorted_items = sorted(items, key=itemgetter('lprice'))

df = pd.json_normalize(sorted_items)
df.to_csv('shop.csv', encoding='utf-8-sig')
filename= 'shop.csv'
myframe = pd.read_csv(filename, encoding='utf-8')
print(myframe)
# Out:
#      Unnamed: 0                                              title  \
# 0             0        샤인 <b>물티슈</b> 캡형 100매 / 부드럽고 도톰한 <b>물티슈</b>
# 1             1                         깨끗한숨 <b>물티슈</b> 100매 캡형 1팩
# 2             2                  쌍용 코디 후레시아 캡형 <b>물티슈</b> 100매 1개입
# 3             3      그린터치 <b>물티슈</b> 캡형 100매 (30개마다 독일 패턴행주 1P 증정)
# 4             4  아기<b>물티슈</b> 그린터치 저자극 순한성분 (100매입x1팩) 캡형 국산 대용...
# ..          ...                                                ...
# 995         995                   앙블랑 폴 베이지 가을에디션 아기<b>물티슈</b> 72매
# 996         996                  BROWN VIP 골드 블랙 <b>물티슈</b> 캡형 70매
# 997         997                       몽베르 프리미어 아기<b>물티슈</b> 캡형 70매
# 998         998                    하기스 네이처메이드 밤부 <b>물티슈</b> 캡형 70매
# 999         999                   앙블랑 세이프 블루나잇 아기<b>물티슈</b> 캡형 70매
#
#                                                   link  \
# 0    https://search.shopping.naver.com/gate.nhn?id=...
# 1    https://search.shopping.naver.com/gate.nhn?id=...
# 2    https://search.shopping.naver.com/gate.nhn?id=...
# 3    https://search.shopping.naver.com/gate.nhn?id=...
# 4    https://search.shopping.naver.com/gate.nhn?id=...
# ..                                                 ...
# 995  https://search.shopping.naver.com/gate.nhn?id=...
# 996  https://search.shopping.naver.com/gate.nhn?id=...
# 997  https://search.shopping.naver.com/gate.nhn?id=...
# 998  https://search.shopping.naver.com/gate.nhn?id=...
# 999  https://search.shopping.naver.com/gate.nhn?id=...
#
#                                                  image  lprice  hprice  \
# 0    https://shopping-phinf.pstatic.net/main_827271...     590     NaN
# 1    https://shopping-phinf.pstatic.net/main_871211...     590     NaN
# 2    https://shopping-phinf.pstatic.net/main_822248...     630     NaN
# 3    https://shopping-phinf.pstatic.net/main_802058...     650     NaN
# 4    https://shopping-phinf.pstatic.net/main_822894...     650     NaN
# ..                                                 ...     ...     ...
# 995  https://shopping-phinf.pstatic.net/main_353006...   56140     NaN
# 996  https://shopping-phinf.pstatic.net/main_451942...   77800     NaN
# 997  https://shopping-phinf.pstatic.net/main_230561...   80000     NaN
# 998  https://shopping-phinf.pstatic.net/main_227651...   81860     NaN
# 999  https://shopping-phinf.pstatic.net/main_220937...  368550     NaN
#
#     mallName    productId  productType  brand   maker category1 category2  \
# 0     유아플러스몰  82727109184            2    NaN   SHINE     출산/육아       물티슈
# 1      마니싸마켓  87121140561            2      숨    광진산업     출산/육아       물티슈
# 2      포스트에스  82224891244            2   CODI  프로스테믹스     출산/육아       물티슈
# 3      해피 키친  80205817617            2    NaN      장원     출산/육아       물티슈
# 4     샤론아이엔씨  82289464982            2    NaN      장원     출산/육아       물티슈
# ..       ...          ...          ...    ...     ...       ...       ...
# 995      네이버  35300698619            1    앙블랑  태남메디코스     출산/육아       물티슈
# 996      네이버  45194292618            1  BROWN    한울생약     출산/육아       물티슈
# 997      네이버  23056110490            1    몽베르      베셀     출산/육아       물티슈
# 998      네이버  22765112926            1    하기스   유한킴벌리     출산/육아       물티슈
# 999      네이버  22093791358            1    앙블랑  태남메디코스     출산/육아       물티슈
#
#     category3  category4
# 0          캡형        NaN
# 1          캡형        NaN
# 2          캡형        NaN
# 3          캡형        NaN
# 4          캡형        NaN
# ..        ...        ...
# 995        캡형        NaN
# 996        캡형        NaN
# 997        캡형        NaN
# 998        캡형        NaN
# 999        캡형        NaN
#
# [1000 rows x 15 columns]
